# %%
import pandas as pd

# %%
df=pd.read_csv('/kaggle/input/spotifyclassification/data.csv')
df
# Out:
#       Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0              0       0.01020         0.833       204600   0.434
# 1              1       0.19900         0.743       326933   0.359
# 2              2       0.03440         0.838       185707   0.412
# 3              3       0.60400         0.494       199413   0.338
# 4              4       0.18000         0.678       392893   0.561
# ...          ...           ...           ...          ...     ...
# 2012        2012       0.00106         0.584       274404   0.932
# 2013        2013       0.08770         0.894       182182   0.892
# 2014        2014       0.00857         0.637       207200   0.935
# 2015        2015       0.00164         0.557       185600   0.992
# 2016        2016       0.00281         0.446       204520   0.915
#
#       instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0             0.021900    2    0.1650    -8.795     1       0.4310  150.062
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0           0        0.0102         0.833       204600   0.434
# 1           1        0.1990         0.743       326933   0.359
# 2           2        0.0344         0.838       185707   0.412
# 3           3        0.6040         0.494       199413   0.338
# 4           4        0.1800         0.678       392893   0.561
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.021900    2    0.1650    -8.795     1       0.4310  150.062
# 1          0.006110    1    0.1370   -10.401     1       0.0794  160.083
# 2          0.000234    2    0.1590    -7.148     1       0.2890   75.044
# 3          0.510000    5    0.0922   -15.236     1       0.0261   86.468
# 4          0.512000    5    0.4390   -11.648     0       0.0694  174.004
#
#    time_signature  valence  target      song_title            artist
# 0             4.0    0.286       1        Mask Off            Future
# ...

# %%
df.tail(10)
# Out:
#       Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 2007        2007      0.002170         0.639       296276   0.978
# 2008        2008      0.054100         0.646       160408   0.714
# 2009        2009      0.004990         0.595       224000   0.837
# 2010        2010      0.002310         0.624       206013   0.971
# 2011        2011      0.000586         0.528       245053   0.879
# 2012        2012      0.001060         0.584       274404   0.932
# 2013        2013      0.087700         0.894       182182   0.892
# 2014        2014      0.008570         0.637       207200   0.935
# 2015        2015      0.001640         0.557       185600   0.992
# 2016        2016      0.002810         0.446       204520   0.915
#
#       instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 2007          0.112000   11    0.0838    -2.376     1       0.0730  144.986
# 2008          0.000000    0    0.1340    -6.511     1       0.0378   97.957
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2017 entries, 0 to 2016
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        2017 non-null   int64
#  1   acousticness      2017 non-null   float64
#  2   danceability      2017 non-null   float64
#  3   duration_ms       2017 non-null   int64
#  4   energy            2017 non-null   float64
#  5   instrumentalness  2017 non-null   float64
#  6   key               2017 non-null   int64
#  7   liveness          2017 non-null   float64
#  8   loudness          2017 non-null   float64
#  9   mode              2017 non-null   int64
#  10  speechiness       2017 non-null   float64
#  11  tempo             2017 non-null   float64
#  12  time_signature    2017 non-null   float64
#  13  valence           2017 non-null   float64
#  14  target            2017 non-null   int64
#  15  song_title        2017 non-null   object
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0            int64
# acousticness        float64
# danceability        float64
# duration_ms           int64
# energy              float64
# instrumentalness    float64
# key                   int64
# liveness            float64
# loudness            float64
# mode                  int64
# speechiness         float64
# tempo               float64
# time_signature      float64
# valence             float64
# target                int64
# song_title           object
# artist               object
# dtype: object

# %%
df.sort_values('danceability')[['song_title']].head(10)
# Out:
#                                              song_title
# 729                                          Bumpy Road
# 532                                     Wake Bake Skate
# 817   Mozart: Requiem in D Minor, K. 626: VIII. Lacr...
# 1600         Trio Sonata in G Major, Wq. 144: I. Adagio
# 1598  Piano Quartet in E flat, Op.47: 3. Andante can...
# 522                                               Outro
# 1348               Be My Valentine (feat. Dickie Allen)
# 1464                                         Right Here
# 1313                                    Senseless Order
# 1306                                               Ruin

# %%
df.sort_values('danceability')[['song_title','artist']].tail(10)
# Out:
#                   song_title             artist
# 1591      Little Green Apple        Tumble Tots
# 623            I'm Different           2 Chainz
# 138     Sippin On Some Syrup      Three 6 Mafia
# 1977                 Fuck Kd         StaRR Lyfe
# 1136                Bad Liar       Selena Gomez
# 32               Best Friend         Young Thug
# 1957            Ice Ice Baby        Vanilla Ice
# 604        Check Me Out Like          Blaqstarr
# 1901                SexyBack  Justin Timberlake
# 1433  Flashwind - Radio Edit       Ben Remember

# %%
df.sort_values('duration_ms')[['song_title','artist','duration_ms']].tail(10)
# Out:
#                                              song_title  \
# 1602  String Quintet in C Major, Op. 29: II. Adagio ...
# 304                              Night on Bald Mountain
# 858                              Night on Bald Mountain
# 404                     Who Is He And What Is He To You
# 335                                              Zombie
# 1565                                      Gloomy Sunday
# 1603  Viola Sonata in C Minor: III. Andante con vari...
# 819                                 Southern Man - Live
# 695   Music Is the Answer - Original Extended 12-Inc...
# 1535                                The Nearness of You
#
#                             artist  duration_ms
# 1602          Ludwig van Beethoven       649415
# 304              Modest Mussorgsky       659560
# 858              Modest Mussorgsky       700027
# 404                Creative Source       703107
# 335                      Fela Kuti       745653
# 1565             Branford Marsalis       763467
# ...

# %%
#Top 10 energetic songs that have duration>400000
df_filter1=df[df['duration_ms']<400000]
df_filter2=df_filter1.sort_values('energy',ascending=False)[['song_title','artist','duration_ms','energy']].head(10)
df_filter2
# Out:
#                song_title                    artist  duration_ms  energy
# 1299        No Absolution         Thy Art Is Murder       201783   0.998
# 1322           Pitchblack  Walking Dead On Broadway       221776   0.997
# 1297    A Darkened Gospel      A Wake in Providence       311217   0.994
# 1347           Unanswered           Suicide Silence       135653   0.993
# 2015        First Contact                Twin Moons       185600   0.992
# 1332      Beautiful Agony          Within The Ruins       271560   0.992
# 1680             Paranoia         A Day To Remember       200677   0.992
# 1328  Down into the Abyss               Conjonctive       256920   0.991
# 1296         Black Colors       Victim Of Deception       247533   0.990
# 1681                Hated                 Beartooth       211430   0.990

# %%
df_filter2.to_csv(r'/kaggle/working/spotify_final.csv')

# %%
df_1=df[df['energy']>0.4]
df_1[['song_title']]
# Out:
#                                 song_title
# 0                                 Mask Off
# 2                             Xanny Family
# 4                           Parallel Lines
# 5                                 Sneakin’
# 6                              Childs Play
# ...                                    ...
# 2012   Like A Bitch - Kill The Noise Remix
# 2013                                 Candy
# 2014  Habit - Dack Janiels & Wenzday Remix
# 2015                         First Contact
# 2016                    I Wanna Get Better
#
# [1830 rows x 1 columns]

# %% [markdown]
# **Song title of songs with energy>0.4**

# %%
df2=df[df['duration_ms']>300000]
df2.sort_values('tempo',ascending=False)[['song_title','artist']].head(10)
# Out:
#                                              song_title            artist
# 412                                              Lazuli       Beach House
# 942                                            Remember       Gino Soccio
# 729                                          Bumpy Road  Destruction Unit
# 1560                       Emperor Jones - Instrumental        Joe Lovano
# 992   Swerve... the reeping of all that is worthwhil...   Shabazz Palaces
# 4                                        Parallel Lines       Junior Boys
# 214                                 Blood On The Leaves        Kanye West
# 1090  Sola (Remix) [feat. Daddy Yankee, Wisin, Farru...          Anuel Aa
# 712                                 Stoned and Starving    Parquet Courts
# 1520                                      Mommy's Shawl   Yelena Eckemoff

# %% [markdown]
# **Songs less than 300s the top 10 fastest songs**

# %%
df3=df.loc[df['artist']=='Drake']
df4=df3.loc[df3['energy']>0.5]
df4['song_title']
# Out:
# 5                      Sneakin’
# 37                      Jumpman
# 117               Hotline Bling
# 154                   Big Rings
# 440                   Headlines
# 589     Started From the Bottom
# 779     0 To 100 / The Catch Up
# 1016           Skepta Interlude
# 1218            Best I Ever Had
# 1223                  Take Care
# Name: song_title, dtype: object

# %% [markdown]
# **Songs by Drake that have energy greater than 0.5**

# %%
df_ins=df.sort_values('instrumentalness',ascending=False)[['instrumentalness','song_title','artist']].head(10)
df_ins
# Out:
#       instrumentalness                            song_title  \
# 1313             0.976                       Senseless Order
# 271              0.968  So Destroyed (channeling Rage Peace)
# 1575             0.964             A Hundred Dreams from Now
# 1619             0.958                                 Raven
# 725              0.957                     Strandbar (disko)
# 1546             0.956                        Almas vaggvisa
# 1322             0.955                            Pitchblack
# 1349             0.954                       Prismatic Abyss
# 1661             0.954                               Yebisah
# 121              0.952                        Chasing Heaven
#
#                         artist
# 1313        Signs of the Swarm
# 271                Prince Rama
# 1575                Ray Bryant
# 1619             John Dahlbäck
# 725                 Todd Terje
# 1546         Jan Lundgren Trio
# 1322  Walking Dead On Broadway
# 1349           Aversions Crown
# ...

# %%
artist_names=df['artist'].value_counts()
artist_names=artist_names.head(10)
artist_names
# Out:
# artist
# Drake              16
# Rick Ross          13
# Disclosure         12
# WALK THE MOON      10
# Backstreet Boys    10
# Crystal Castles     9
# FIDLAR              9
# Future              8
# Fall Out Boy        8
# Skrillex            8
# Name: count, dtype: int64

# %%
df_top=df[df['artist'].isin(artist_names.index)]
df_top
# Out:
#       Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0              0      0.010200         0.833       204600   0.434
# 2              2      0.034400         0.838       185707   0.412
# 5              5      0.004790         0.804       251333   0.560
# 6              6      0.014500         0.739       241400   0.472
# 15            15      0.019000         0.637       188333   0.832
# ...          ...           ...           ...          ...     ...
# 1990        1990      0.000590         0.594       218720   0.858
# 1991        1991      0.000366         0.544       245133   0.788
# 1992        1992      0.007490         0.446       241253   0.881
# 1993        1993      0.001900         0.551       195280   0.732
# 1994        1994      0.510000         0.630       240000   0.772
#
#       instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0             0.021900    2    0.1650    -8.795     1       0.4310  150.062
# ...

# %% [markdown]
# **df_top contains only the top 10 artist songs**

# %%
tempo_mean=df_top.groupby('artist')['tempo'].mean()
tempo_mean
# Out:
# artist
# Backstreet Boys    113.066600
# Crystal Castles    128.600778
# Disclosure         128.118417
# Drake              112.406750
# FIDLAR             145.983444
# Fall Out Boy       133.815625
# Future             128.989625
# Rick Ross          110.721923
# Skrillex           132.454125
# WALK THE MOON      136.163600
# Name: tempo, dtype: float64

# %% [markdown]
# **Mean tempo of each of top 10 occurring artist**
